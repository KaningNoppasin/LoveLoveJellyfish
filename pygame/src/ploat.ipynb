# %%
import matplotlib.pyplot as plt

# New provided data as a list
data = [
    342249.20068263, 223198.65619138, 281592.73106644, 199101.10291804,
    260210.32158925, 289372.03443088, 118445.10263401, 196720.04424405,
    238023.7058729, 143773.84362722, 162358.95748146, 86485.39392374,
    43676.23717002, 208234.60781484, 83570.58620143, 188443.05472667,
    68735.21922254, 61601.20543255, 180937.81789091, 88030.33427122,
    81805.3825697, 100529.00765296, 32036.83988426, 191256.66379376,
    94177.76789715, 135615.40721553, 176997.2360104, 159415.87435012,
    141035.22050087, 65062.55455744, 172483.62135848, 99863.30979174,
    58462.34407032, 126351.9325971, 178654.37724574, 105797.23926138,
    222636.2845348, 53134.0, 222636.2845348, 105797.23926138,
    178654.37724574, 126351.9325971, 58462.34407032, 99863.30979174,
    172483.62135848, 65062.55455744, 141035.22050087, 159415.87435012,
    176997.2360104, 135615.40721553, 94177.76789715, 191256.66379376,
    32036.83988426, 100529.00765296, 81805.3825697, 88030.33427122,
    180937.81789091, 61601.20543255, 68735.21922254, 188443.05472667,
    83570.58620143, 208234.60781484, 43676.23717002, 86485.39392374,
    162358.95748146, 143773.84362722, 238023.7058729, 196720.04424405,
    118445.10263401, 289372.03443088, 260210.32158925, 199101.10291804,
    281592.73106644, 223198.65619138, 342249.20068263, 52598.30257711,
    164681.4494141, 244542.16456018
]

# Create a figure and axis
plt.figure(figsize=(12, 6))

# Plot the data
plt.plot(data, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.title('ADC Values Plot')
plt.xlabel('Sample Index')
plt.ylabel('ADC Value')
plt.grid(True)

# Show the plot
plt.show()
